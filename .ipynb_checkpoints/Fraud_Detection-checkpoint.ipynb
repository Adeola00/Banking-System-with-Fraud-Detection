# %% [markdown]
# # BANKING SYSTEM WITH FRAUD DETECTION ALGORITHM

# %%
class BankAccount:
    def __init__(self, first_name, last_name,middle_name,age,gender,pin,confirm_pin):
        self.first_name = first_name
        self.last_name = last_name
        self.middle_name =middle_name
        self.age = age
        self.agender = gender
        self.pin = pin
        self.confirm_pin = confirm_pin
        self.account_balance = 0
        self.transaction = []
        
    def __repr__(self):
        return f" {self.first_name} - {str(self.account_balance)}, Withdrawals - {str(self.transaction)}"
    
    def deposit(self, amount):
        self.account_balance += float(amount)
        
    def withdraw(self, amount):
        self.account_balance -= float(amount)
        self.transaction.append(amount)
        
    def get_balance(self):
        return self.account_balance
    
    #Sort the given list and Check for the median
    def sort_median(self,lists):
        import numpy as np
        max_element = max(lists)
        bucket = [0 for i in np.arange(max_element+1)]
        for element in lists:
            bucket[int(element)]+=1
        sorted_list = []
        for idx,count in enumerate(bucket):
            sorted_list.extend([idx]*count)
        length = len(sorted_list)
        if length%2 ==0:
            low_index = (length//2)-1
            upper_index = (length//2)
            low,upper = sorted_list[low_index],sorted_list[upper_index]
            mid = (low+upper)/2
            return mid
        else:
            index = length//2
            return sorted_list[index]
        return sorted_list
    
    #Checks for Fraudulent Alert

    def fraudulent_alert(self,lists):    
        length_of_trailing_days = 3
        length = len(lists)
        count = 0
        transaction = []
        for idx in range(1,length+1):
            if idx <= length_of_trailing_days:
                pass
            else:
                cut_list = lists[:idx]
                length = len(cut_list)
                low_index = length-length_of_trailing_days
                new_list = cut_list[low_index-1:length-1]
                median = self.sort_median(new_list)
           # print(new_list)
                if median < lists[idx-1]:
                    count+=1
                    transaction.append(lists[idx-1])
        return (count,transaction)

# %%
class Bank:
    def __init__(self):
        self.accounts = {}
    # Available operations
    def bank_operations(self):
        option = None
        while option != "5":
            print(' 1. Create an Account \n','2. Deposits \n','3. Withdrawals \n','4. Get balance\n','5. Exit \n','6. Fraud Check \n')
            print(self.accounts)
            option = input("Enter option:")
            if option == "1":
                print("Create account!!")
                self.create_account()
            elif option == "2":
                self.deposit()
            elif option == "4":
                account_num = input("Enter account number:")
                account = self.accounts[account_num]
                print(f"Your balance is ${account.get_balance():.2f}")
            elif option == "3":
                self.withdraw()
            elif option == "6":
                print(self.check_for_fraud())
                
        else:
            print("Thank you for banking with us.")
    #getting personal details
    def create_account(self):
        first_name = input('Enter First Name ').title()
        if first_name == "":
            print("\n Invalid Name. \n")
            return
        last_name = input('Enter Last Name ').title()
        if last_name == "":
            print("\n Invalid Name. \n")
            return
        middle_name = input('Enter Middle Name ').title()
        if middle_name == "":
            print("\n Invalid Name. \n")
            return
        try:
            age = int(input('Enter Age '))
            if age < 18:
                print("You are not old enough to create an account.")
        except ValueError:
            print("\n Invalid age. \n")
            return
        gender = input('Enter Gender \n(M, F or Other): ').upper()
        if (gender !="M") and (gender !="F") and (gender != "OTHER"):
            print("Enter a valid gender")
            return
        account_balance = 0
        transaction = [] 
        pin = input("Create a 4-digit PIN ")
        confirm_pin = input("Confirm PIN ")
        if pin != confirm_pin:
            print("\n Inconsistent PIN. \n")
            return
        if len(pin) != 4 and len(confirm_pin) != 4:
            print("\n Invalid PIN \n")
            return
        new_account = BankAccount(first_name, last_name,middle_name,age,gender,pin,confirm_pin)
        account_number = self.account_number()
        self.accounts[account_number] = new_account
        print(f"Welcome, {first_name}. Your account number is {account_number}.")
#         with open('account_information.txt','a') as acc:
#             acc.write(f'{last_name} {first_name} {middle_name} {age} {gender} {account_balance} {account_number} {transaction}\n') 
            
    #Generating account number 
    def account_number(self):
        import random 
        account_no = ''
        for i in range(9):
            num =random.randint(0,9)
            account_no += str(num)
        return account_no
    def deposit(self):
        account_number = input("Enter your account number: ")
        amount = float(input("Enter an amount: "))
        if account_number not in self.accounts.keys():
            print("\n Account number not available. \n")
            return
        account = self.accounts[account_number]
        account.deposit(amount)
    def withdraw(self):
        account_number = input("Enter your account number: ")
        amount = float(input("Enter an amount: "))
        withdraw_pin = input("Enter your pin: ")
        if account_number not in self.accounts.keys():
            print("\n Account number not available. \n")
            return
        account = self.accounts[account_number]
        if withdraw_pin != account.pin:
            print("\n Inavlid PIN \n")
            return
        balance = account.get_balance()
        if amount > balance:
            print("\n INSUFFICIENT FUNDS. \n")
            return
        account.withdraw(amount)
    def check_for_fraud(self):
        account_number = input("Enter your account number: ")
        if account_number not in self.accounts.keys():
            print("\n Account number not available. \n")
            return
        account = self.accounts[account_number]
        return account.fraudulent_alert(account.transaction)

# %%
# def fradulent_check(filename):
#     filename = filename+'.txt'
#     with open(filename) as file:
#         detail = {}
#         new_lst = []
#         for line in file:
#             account_no = line.strip().split(',')[1]
#             items = line.strip().split(',')[3:]
#             items_n = [int(item) for item in items]
#             detail[account_no] = fraudulent_alert(items_n)




#     return detail         #print(type(items))

# %%
b = Bank()

# %%
b.bank_operations()
# Out:
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {}
# Enter option:1
# Create account!!
# Enter First Name Sk
# Enter Last Name OD
# Enter Middle Name OT
# Enter Age 24
# Enter Gender
# (M, F or Other): M
# Create a 4-digit PIN 2020
# Confirm PIN 2020
# Welcome, Sk. Your account number is 062737030.
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 0, Withdrawals - []}
# Enter option:2
# Enter your account number: 062737030
# Enter an amount: 20000
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 20000.0, Withdrawals - []}
# Enter option:3
# Enter your account number: 062737030
# Enter an amount: 200
# Enter your pin: 2020
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 19800.0, Withdrawals - [200.0]}
# Enter option:3
# Enter your account number: 062737030
# Enter an amount: 500
# Enter your pin: 2020
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 19300.0, Withdrawals - [200.0, 500.0]}
# Enter option:3
# Enter your account number: 062737030
# Enter an amount: 300
# Enter your pin: 2020
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 19000.0, Withdrawals - [200.0, 500.0, 300.0]}
# Enter option:3
# Enter your account number: 062737030
# Enter an amount: 1000
# Enter your pin: 2020
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 18000.0, Withdrawals - [200.0, 500.0, 300.0, 1000.0]}
# Enter option:6
# Enter your account number: 062737030
# (1, [1000.0])
#  1. Create an Account
#  2. Deposits
#  3. Withdrawals
#  4. Get balance
#  5. Exit
#  6. Fraud Check
#
# {'062737030':  Sk - 18000.0, Withdrawals - [200.0, 500.0, 300.0, 1000.0]}
